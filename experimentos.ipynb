# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('rendimiento_2018.csv', delimiter=';')
data.head()
# Out:
# C:\Users\danie\AppData\Roaming\Python\Python39\site-packages\IPython\core\interactiveshell.py:3441: DtypeWarning: Columns (25) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#    AGNO  RBD  DGV_RBD                  NOM_RBD  COD_REG_RBD NOM_REG_RBD_A  \
# 0  2018    1        9  LICEO POLITECNICO ARICA           15           AYP
# 1  2018    1        9  LICEO POLITECNICO ARICA           15           AYP
# 2  2018    1        9  LICEO POLITECNICO ARICA           15           AYP
# 3  2018    1        9  LICEO POLITECNICO ARICA           15           AYP
# 4  2018    1        9  LICEO POLITECNICO ARICA           15           AYP
#
#    COD_PRO_RBD  COD_COM_RBD NOM_COM_RBD  COD_DEPROV_RBD  ... COD_REG_ALU  \
# 0          151        15101       ARICA             151  ...          15
# 1          151        15101       ARICA             151  ...          15
# 2          151        15101       ARICA             151  ...          15
# 3          151        15101       ARICA             151  ...          15
# 4          151        15101       ARICA             151  ...          15
#
#    COD_COM_ALU  NOM_COM_ALU  COD_RAMA  COD_SEC  COD_ESPE  PROM_GRAL  \
# 0        15101        ARICA       400      410     41001          0
# 1        15101        ARICA       400      410     41001          0
# 2        15101        ARICA       400      410     41001          0
# 3        15101        ARICA       400      410     41001        6,4
# 4        15101        ARICA       400      410     41001          0
#
#    ASISTENCIA SIT_FIN  SIT_FIN_R
# 0           0       Y          T
# 1           0       Y          Y
# 2           0       Y          T
# 3          95       P          P
# 4           0       Y          Y
#
# [5 rows x 36 columns]

# %%
data.columns
# Out:
# Index(['AGNO', 'RBD', 'DGV_RBD', 'NOM_RBD', 'COD_REG_RBD', 'NOM_REG_RBD_A',
#        'COD_PRO_RBD', 'COD_COM_RBD', 'NOM_COM_RBD', 'COD_DEPROV_RBD',
#        'NOM_DEPROV_RBD', 'COD_DEPE', 'COD_DEPE2', 'RURAL_RBD', 'ESTADO_ESTAB',
#        'COD_ENSE', 'COD_ENSE2', 'COD_GRADO', 'LET_CUR', 'COD_JOR',
#        'COD_TIP_CUR', 'COD_DES_CUR', 'MRUN', 'GEN_ALU', 'FEC_NAC_ALU',
#        'EDAD_ALU', 'COD_REG_ALU', 'COD_COM_ALU', 'NOM_COM_ALU', 'COD_RAMA',
#        'COD_SEC', 'COD_ESPE', 'PROM_GRAL', 'ASISTENCIA', 'SIT_FIN',
#        'SIT_FIN_R'],
#       dtype='object')

# %%
ic = data[[
    'RBD', 'RURAL_RBD', 'ASISTENCIA', 'GEN_ALU',
    'COD_JOR', 'COD_DEPE', 'COD_COM_ALU', 'COD_COM_RBD',
    'PROM_GRAL'
    # 'COD_REG_RBD',
]]
ic = ic.drop(ic[ic['PROM_GRAL'] == "0"].index)
ic
# Out:
#            RBD  RURAL_RBD  ASISTENCIA  GEN_ALU  COD_JOR  COD_DEPE  \
# 3            1          0          95        2        4         2
# 8            1          0          90        1        4         2
# 15           1          0          97        2        4         2
# 16           1          0          94        1        4         2
# 17           1          0          90        2        4         2
# ...        ...        ...         ...      ...      ...       ...
# 3293745  41063          0         100        2        2         3
# 3293746  41063          0         100        1        2         3
# 3293747  41063          0         100        1        2         3
# 3293748  41063          0         100        1        2         3
# 3293749  41063          0         100        2        2         3
#
#          COD_COM_ALU  COD_COM_RBD PROM_GRAL
# 3              15101        15101       6,4
# 8              15101        15101       5,3
# 15             15101        15101       6,4
# 16             15101        15101         6
# 17             15101        15101       5,8
# ...              ...          ...       ...
# 3293745        15101        15101       6,3
# 3293746        15101        15101       6,1
# 3293747        15101        15101       6,3
# 3293748        15101        15101       5,9
# 3293749         3301        15101       5,4
#
# [2998634 rows x 9 columns]

# %%
ic['PROM_GRAL'] = ic['PROM_GRAL'].apply(lambda x: x.replace(",", ".")).astype(np.float)
ic.astype(float)
# Out:
# C:\Users\danie\AppData\Local\Temp/ipykernel_1448/3040759384.py:1: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   ic['PROM_GRAL'] = ic['PROM_GRAL'].apply(lambda x: x.replace(",", ".")).astype(np.float)
#              RBD  RURAL_RBD  ASISTENCIA  GEN_ALU  COD_JOR  COD_DEPE  \
# 3            1.0        0.0        95.0      2.0      4.0       2.0
# 8            1.0        0.0        90.0      1.0      4.0       2.0
# 15           1.0        0.0        97.0      2.0      4.0       2.0
# 16           1.0        0.0        94.0      1.0      4.0       2.0
# 17           1.0        0.0        90.0      2.0      4.0       2.0
# ...          ...        ...         ...      ...      ...       ...
# 3293745  41063.0        0.0       100.0      2.0      2.0       3.0
# 3293746  41063.0        0.0       100.0      1.0      2.0       3.0
# 3293747  41063.0        0.0       100.0      1.0      2.0       3.0
# 3293748  41063.0        0.0       100.0      1.0      2.0       3.0
# 3293749  41063.0        0.0       100.0      2.0      2.0       3.0
#
#          COD_COM_ALU  COD_COM_RBD  PROM_GRAL
# 3            15101.0      15101.0        6.4
# 8            15101.0      15101.0        5.3
# 15           15101.0      15101.0        6.4
# 16           15101.0      15101.0        6.0
# 17           15101.0      15101.0        5.8
# ...              ...          ...        ...
# 3293745      15101.0      15101.0        6.3
# 3293746      15101.0      15101.0        6.1
# 3293747      15101.0      15101.0        6.3
# 3293748      15101.0      15101.0        5.9
# 3293749       3301.0      15101.0        5.4
#
# [2998634 rows x 9 columns]

# %%
regr_columns = ic[['RBD', 'RURAL_RBD', 'ASISTENCIA', 'GEN_ALU', 'PROM_GRAL']]

# %%
regr_columns['SAME_COM'] = (ic.COD_COM_ALU == ic.COD_COM_RBD).astype(int)
depe = ['corp_munic', 'munic_daem', 'particular_sub', 'particular_pag', 'corp_admin_pag', 'serv_loc_ed']
for i in range(1, 7):
    regr_columns[depe[i - 1]] = (ic.COD_DEPE == i).astype(int)

jor = ['ma', 'tar', 'completa', 'vesp']
for i in range(1, 5):
    regr_columns[jor[i - 1]] = (ic.COD_JOR == i).astype(int)

regr_columns
# Out:
# C:\Users\danie\AppData\Local\Temp/ipykernel_1448/2702740385.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   regr_columns['SAME_COM'] = (ic.COD_COM_ALU == ic.COD_COM_RBD).astype(int)
# C:\Users\danie\AppData\Local\Temp/ipykernel_1448/2702740385.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   regr_columns[depe[i - 1]] = (ic.COD_DEPE == i).astype(int)
#            RBD  RURAL_RBD  ASISTENCIA  GEN_ALU  PROM_GRAL  SAME_COM  \
# 3            1          0          95        2        6.4         1
# 8            1          0          90        1        5.3         1
# 15           1          0          97        2        6.4         1
# 16           1          0          94        1        6.0         1
# 17           1          0          90        2        5.8         1
# ...        ...        ...         ...      ...        ...       ...
# 3293745  41063          0         100        2        6.3         1
# 3293746  41063          0         100        1        6.1         1
# 3293747  41063          0         100        1        6.3         1
# 3293748  41063          0         100        1        5.9         1
# 3293749  41063          0         100        2        5.4         0
#
#          corp_munic  munic_daem  particular_sub  particular_pag  \
# 3                 0           1               0               0
# 8                 0           1               0               0
# 15                0           1               0               0
# 16                0           1               0               0
# 17                0           1               0               0
# ...             ...         ...             ...             ...
# 3293745           0           0               1               0
# 3293746           0           0               1               0
# 3293747           0           0               1               0
# 3293748           0           0               1               0
# 3293749           0           0               1               0
#
#          corp_admin_pag  serv_loc_ed  ma  tar  completa  vesp
# 3                     0            0   0    0         0     1
# 8                     0            0   0    0         0     1
# 15                    0            0   0    0         0     1
# 16                    0            0   0    0         0     1
# 17                    0            0   0    0         0     1
# ...                 ...          ...  ..  ...       ...   ...
# 3293745               0            0   0    1         0     0
# 3293746               0            0   0    1         0     0
# 3293747               0            0   0    1         0     0
# 3293748               0            0   0    1         0     0
# 3293749               0            0   0    1         0     0
#
# [2998634 rows x 16 columns]

# %%
from sklearn.linear_model import LinearRegression

regr = LinearRegression()
regr.fit(regr_columns.drop('PROM_GRAL', axis=1), regr_columns['PROM_GRAL'])

print(f'Coeficientes: {regr.coef_}')
print(f'Beta0: {regr.intercept_}')
# Out:
# Coeficientes: [-2.39521439e-06  6.26529218e-02  2.52448812e-02  1.90920057e-01
#   4.68900066e-02 -6.23296865e-02 -3.20646734e-02 -2.44634604e-03
#   3.94917140e-01 -2.82532185e-01 -1.55442496e-02  1.31708346e-01
#   2.21133868e-01  7.87159059e-02 -4.31558119e-01]
# Beta0: 3.0613669017195284

# %%
regr_columns.drop('PROM_GRAL', axis=1).columns[np.argmax(regr.coef_)]
# Out:
# 'particular_pag'

# %%
sample = regr_columns.sample(30)
sample
# Out:
#            RBD  RURAL_RBD  ASISTENCIA  GEN_ALU  PROM_GRAL  SAME_COM  \
# 1837344  10415          0          90        2        6.6         0
# 739958    3995          1          99        1        5.8         1
# 583835                0            0   0    0         1     0
# 2928620               0            0   1    0         0     0
# 577605                0            0   0    0         1     0
# 2496164               0            0   0    0         0     1
# 1533273               0            0   0    0         1     0
# 2884404               0            0   0    1         0     0

# %%
regr.predict(sample.drop('PROM_GRAL', axis=1))
# Out:
# array([5.81956216, 5.89815547, 5.71394313, 5.83509275, 5.86794292,
#        6.09292224, 5.73251804, 5.23393874, 6.20643907, 5.73752423,
#        5.66204083, 5.68997999, 5.8426916 , 5.56144024, 5.39804441,
#        5.60511354, 5.85440981, 5.95970362, 5.67730761, 5.76498334,
#        5.84521001, 5.51027668, 5.52600609, 5.60200694, 4.9414488 ,
#        5.93198252, 5.64842763, 5.32390068, 5.42676961, 6.0629162 ])

# %%
prom_pred = regr.predict(regr_columns.drop('PROM_GRAL', axis=1))

# %%
from sklearn.metrics import mean_squared_error, r2_score

print(f'MSE: {mean_squared_error( regr_columns["PROM_GRAL"], prom_pred)}')
print(f'R2: {r2_score( regr_columns["PROM_GRAL"], prom_pred)}')
# Out:
# MSE: 0.36228446671059905
# R2: 0.20432415871448562

# %%
save_data = ic[[
    'RBD', 'RURAL_RBD', 'ASISTENCIA', 'GEN_ALU',
    'COD_JOR', 'COD_DEPE', 'PROM_GRAL'
    ]]
save_data['SAME_COM'] = (ic.COD_COM_ALU == ic.COD_COM_RBD).astype(int)
save_data
# Out:
# C:\Users\danie\AppData\Local\Temp/ipykernel_1448/2838457795.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   save_data['SAME_COM'] = (ic.COD_COM_ALU == ic.COD_COM_RBD).astype(int)
#            RBD  RURAL_RBD  ASISTENCIA  GEN_ALU  COD_JOR  COD_DEPE  PROM_GRAL  \
# 3            1          0          95        2        4         2        6.4
# 8            1          0          90        1        4         2        5.3
# 15           1          0          97        2        4         2        6.4
# 16           1          0          94        1        4         2        6.0
# 17           1          0          90        2        4         2        5.8
# ...        ...        ...         ...      ...      ...       ...        ...
# 3293745  41063          0         100        2        2         3        6.3
# 3293746  41063          0         100        1        2         3        6.1
# 3293747  41063          0         100        1        2         3        6.3
# 3293748  41063          0         100        1        2         3        5.9
# 3293749  41063          0         100        2        2         3        5.4
#
#          SAME_COM
# 3               1
# 8               1
# 15              1
# 16              1
# 17              1
# ...           ...
# 3293745         1
# 3293746         1
# 3293747         1
# 3293748         1
# 3293749         0
#
# [2998634 rows x 8 columns]

# %%
save_data.sample(1000).to_json('E3/data.json', orient='records')

# %%
save_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2998634 entries, 3 to 3293749
# Data columns (total 8 columns):
#  #   Column      Dtype
# ---  ------      -----
#  0   RBD         int64
#  1   RURAL_RBD   int64
#  2   ASISTENCIA  int64
#  3   GEN_ALU     int64
#  4   COD_JOR     int64
#  5   COD_DEPE    int64
#  6   PROM_GRAL   float64
#  7   SAME_COM    int32
# dtypes: float64(1), int32(1), int64(6)
# memory usage: 194.5 MB

# %%
unique = np.unique(data[['COD_COM_RBD']])
unique.shape
# Out:
# (346,)
